# %% [markdown]
# # Geographic Data Exploration

# %%
# Import libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import snowflake.connector
from skimage import io

# %%
# Read in Snowflake credentials
with open('credentials.txt', 'r') as f:
    creds = f.readlines()
    USER = creds[0].strip()
    PASSWORD = creds[1].strip()
    ACCOUNT = creds[2].strip()

# %%
# Open a connection and test that it works
con = snowflake.connector.connect(
    user=USER,
    password=PASSWORD,
    account=ACCOUNT,
)
cs = con.cursor()
cs.execute("SELECT current_version()")
one_row = cs.fetchone()
print(one_row[0])
# Out:
# 7.31.1

# %% [markdown]
# ### Shapes Data

# %%
# Import data as a Pandas Dataframe and preview
cs.execute("SELECT * FROM DEV.JUSTIN.SHAPES")
shape_data = cs.fetch_pandas_all()
shape_data
# Out:
#         shape_id  shape_distance_traveled  shape_latitude  shape_longitude  \
# 0         546042                   3355.3       45.544365      -122.936581
# 1         546042                   3430.8       45.544181      -122.936716
# 2         546042                   3495.0       45.544022      -122.936824
# 3         546042                   3546.6       45.543892      -122.936903
# 4         546042                   3644.5       45.543640      -122.937035
# ...          ...                      ...             ...              ...
# 627466    543823                    581.8       45.521378      -122.989795
# 627467    543823                    613.6       45.521377      -122.989671
# 627468    543823                    661.5       45.521377      -122.989484
# 627469    543823                    723.6       45.521379      -122.989242
# 627470    543823                    855.3       45.521380      -122.988728
#
#         shape_sequence
# 0                   56
# 1                   57
# 2                   58
# 3                   59
# 4                   60
# ...                ...
# 627466              22
# 627467              23
# 627468              24
# 627469              25
# 627470              26
#
# [627471 rows x 5 columns]

# %%
# Determine number of unique shapes
unique_shapes = shape_data['shape_id'].unique()
len(unique_shapes)
# Out:
# 923

# %%
# Filter down to an arbitrary shape
arbitrary_shape_data = shape_data.loc[shape_data['shape_id'] == unique_shapes[0]]
arbitrary_shape_data
# Out:
#         shape_id  shape_distance_traveled  shape_latitude  shape_longitude  \
# 0         546042                   3355.3       45.544365      -122.936581
# 1         546042                   3430.8       45.544181      -122.936716
# 2         546042                   3495.0       45.544022      -122.936824
# 3         546042                   3546.6       45.543892      -122.936903
# 4         546042                   3644.5       45.543640      -122.937035
# ...          ...                      ...             ...              ...
# 269995    546042                   3043.1       45.545048      -122.935851
# 269996    546042                   3096.1       45.544941      -122.935991
# 269997    546042                   3142.7       45.544845      -122.936111
# 269998    546042                   3264.7       45.544576      -122.936394
# 269999    546042                   3312.2       45.544465      -122.936491
#
#         shape_sequence
# 0                   56
# 1                   57
# 2                   58
# 3                   59
# 4                   60
# ...                ...
# 269995              51
# 269996              52
# 269997              53
# 269998              54
# 269999              55
#
# [468 rows x 5 columns]

# %%
# Draw the shape
plt.plot(arbitrary_shape_data['shape_longitude'], arbitrary_shape_data['shape_latitude'])

# %% [markdown]
# #### Thoughts on Shapes
#
# * **Mapping to Objects** Looking at the other GTFS tables, these shape ID's correspond to "Trips". Trips in turn have a many-to-one relationship with routes. Not sure what to do with that yet, but it's a start.

# %% [markdown]
# ### Stops Data

# %%
# Import data as a Pandas Dataframe and preview
cs.execute("SELECT * FROM DEV.JUSTIN.STOPS")
stops_data = cs.fetch_pandas_all()
stops_data
# Out:
#             stop_id  stop_latitude  stop_longitude  \
# 0                 2      45.420609     -122.675671
# 1                 3      45.419388     -122.665197
# 2                 4      45.420703     -122.675152
# 3                 6      45.420217     -122.673070
# 4                 7      45.420411     -122.672680
# ...             ...            ...             ...
# 6537  landmark-2563      45.430084     -122.769663
# 6538   landmark-107      45.521301     -122.978373
# 6539   landmark-113      45.510657     -122.716792
# 6540   landmark-106      45.521166     -122.969510
# 6541   landmark-101      45.517246     -122.870196
#
#                                      stop_name
# 0                             A Ave & Chandler
# 1                            A Ave & Second St
# 2                              A Ave & 10th St
# 3                               A Ave & 8th St
# 4                               A Ave & 8th St
# ...                                        ...
# 6537                     Tigard TC WES Station
# 6538   Tuality Hospital/SE 8th Ave MAX Station
# 6539               Washington Park MAX Station
# 6540        Washington/SE 12th Ave MAX Station
# 6541  Willow Creek/SW 185th Ave TC MAX Station
#
# [6542 rows x 4 columns]

# %%
# Try plotting the stops
plt.scatter(stops_data['stop_longitude'], stops_data['stop_latitude'], alpha=0.2)

# %% [markdown]
# #### Thoughts on Stops
#
# * **ID Values** Most of these stops have numeric identifiers. A handful have "landmark-xxx" identifiers though.
#
# * **Redundant Stop Names** Some of these stops have the same name, but are located in a slightly different location.

# %% [markdown]
# ### Current Vehicle Locations

# %%
# Import data as a Pandas Dataframe and preview
cs.execute("SELECT * FROM DEV.JUSTIN.CURRENT_VEHICLE_LOCATIONS")
vehicle_data = cs.fetch_pandas_all()
vehicle_data
# Out:
#      vehicle_id  vehicle_latitude  vehicle_longitude  vehicle_timestamp  \
# 0           101         45.599802        -122.684568      1694033575087
# 1           109         45.508073        -122.681930      1694033551622
# 2           110         45.501818        -122.418515      1694033575035
# 3           111         45.431208        -122.635112      1694033575102
# 4           112         45.524114        -122.564449      1694033572818
# ..          ...               ...                ...                ...
# 420        4511         45.528064        -122.675954      1694033571421
# 421        4512         45.506548        -122.662033      1694033574501
# 422        4514         45.502831        -122.670953      1694033574502
# 423        4515         45.504558        -122.496697      1694033565719
# 424        4527         45.504494        -122.498899      1694033565722
#
#     vehicle_type vehicle_subtype
# 0           rail      Light Rail
# 1           rail      Light Rail
# 2           rail      Light Rail
# 3           rail      Light Rail
# 4           rail      Light Rail
# ..           ...             ...
# 420          bus             BRT
# 421          bus             BRT
# 422          bus             BRT
# 423          bus             BRT
# 424          bus             BRT
#
# [425 rows x 6 columns]

# %%
# Try plotting the vehicles
plt.scatter(vehicle_data['vehicle_longitude'], vehicle_data['vehicle_latitude'], alpha=0.2, color='red')

# %%
# Try plotting the vehicles by type
sns.scatterplot(x='vehicle_longitude', y='vehicle_latitude', data=vehicle_data, alpha=0.6, hue=vehicle_data['vehicle_type'])
# Out:
# <Axes: xlabel='vehicle_longitude', ylabel='vehicle_latitude'>

# %%
# Try plotting the vehicles by subtype
sns.scatterplot(x='vehicle_longitude', y='vehicle_latitude', data=vehicle_data, alpha=0.6, hue=vehicle_data['vehicle_subtype'])
# Out:
# <Axes: xlabel='vehicle_longitude', ylabel='vehicle_latitude'>

# %% [markdown]
# ---

# %% [markdown]
# ### Shapes Revisted
#
# I did some barebones data reworking to map the route data to shapes.

# %%
# Import data as a Pandas Dataframe and preview
cs.execute("SELECT * FROM DEV.JUSTIN.ROUTE_SHAPES")
route_shape_data = cs.fetch_pandas_all()
route_shape_data
# Out:
#         shape_id  shape_distance_traveled  shape_latitude  shape_longitude  \
# 0         545842                      0.0       45.522879      -122.677388
# 1         545842                     12.6       45.522913      -122.677396
# 2         545842                     41.3       45.522988      -122.677431
# 3         545842                    283.6       45.523003      -122.676486
# 4         545842                    289.5       45.523002      -122.676463
# ...          ...                      ...             ...              ...
# 314476    543818                  97972.9       45.321243      -122.576245
# 314477    543818                  98019.8       45.321165      -122.576100
# 314478    543818                  98069.3       45.321275      -122.575987
# 314479    543818                  98114.7       45.321398      -122.575960
# 314480    543818                  98390.7       45.322033      -122.575376
#
#         shape_sequence route_id route_color          route_name  route_type
# 0                    1        1      084C8D             Vermont           3
# 1                    2        1      084C8D             Vermont           3
# 2                    3        1      084C8D             Vermont           3
# 3                    4        1      084C8D             Vermont           3
# 4                    5        1      084C8D             Vermont           3
# ...                ...      ...         ...                 ...         ...
# 314476            1337       99      084C8D  Macadam/McLoughlin           3
# 314477            1338       99      084C8D  Macadam/McLoughlin           3
# 314478            1339       99      084C8D  Macadam/McLoughlin           3
# 314479            1340       99      084C8D  Macadam/McLoughlin           3
# 314480            1341       99      084C8D  Macadam/McLoughlin           3
#
# [314481 rows x 9 columns]

# %%
# Determine number of unique shapes
unique_routes = route_shape_data['shape_id'].unique()
len(unique_routes)
# Out:
# 468

# %%
# Filter down to an arbitrary route
arbitrary_route_data = route_shape_data.loc[route_shape_data['shape_id'] == unique_routes[0]]
arbitrary_route_data
# Out:
#      shape_id  shape_distance_traveled  shape_latitude  shape_longitude  \
# 0      545842                      0.0       45.522879      -122.677388
# 1      545842                     12.6       45.522913      -122.677396
# 2      545842                     41.3       45.522988      -122.677431
# 3      545842                    283.6       45.523003      -122.676486
# 4      545842                    289.5       45.523002      -122.676463
# ..        ...                      ...             ...              ...
# 763    545842                  62463.5       45.476185      -122.720849
# 764    545842                  62489.1       45.476217      -122.720760
# 765    545842                  62506.8       45.476217      -122.720691
# 766    545842                  62606.6       45.476214      -122.720302
# 767    545842                  62613.0       45.476213      -122.720277
#
#      shape_sequence route_id route_color route_name  route_type
# 0                 1        1      084C8D    Vermont           3
# 1                 2        1      084C8D    Vermont           3
# 2                 3        1      084C8D    Vermont           3
# 3                 4        1      084C8D    Vermont           3
# 4                 5        1      084C8D    Vermont           3
# ..              ...      ...         ...        ...         ...
# 763             764        1      084C8D    Vermont           3
# 764             765        1      084C8D    Vermont           3
# 765             766        1      084C8D    Vermont           3
# 766             767        1      084C8D    Vermont           3
# 767             768        1      084C8D    Vermont           3
#
# [768 rows x 9 columns]

# %%
# Draw the route
plot = plt.plot(arbitrary_route_data['shape_longitude'], arbitrary_route_data['shape_latitude'], color=f'#{arbitrary_route_data["route_color"][0]}')
plt.title(f"Route: {arbitrary_route_data['route_name'][0]}")
plot

# %%
# Check against the actual route map
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

f = "https://trimet.org/schedules/img/001.png"
a = io.imread(f)

plt.imshow(a)
plt.axis('off')

plt.show()
